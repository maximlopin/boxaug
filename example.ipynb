# %%
from boxaug.transforms import Compose, Affine, Resize, Flip
from boxaug.utils import to_pil
from boxaug.datasets import Dataset

# %%
tfm = Compose(
    Resize(128, 128),
    Affine(deg=30, shear=(0.3, 0.3)),
    Flip(axis=0),
    Flip(axis=1)
)

# %%
ds = Dataset.from_labelimg('./data', tfm)

# %%
for _ in range(10):
    image, bboxes, labels = ds[0]
    display(to_pil(image, bboxes))
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x2074AA6BA88>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x2074A985D08>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x2074A9F43C8>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x2074AA80B88>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x2074AA80A48>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x2074AA80DC8>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x2074AA80E48>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x2074AA80F88>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x2074AA80DC8>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x2074AA80E48>
