# %%
from boxaug.transforms import Compose, Affine, Resize, Flip
from boxaug.utils import to_pil
from boxaug.datasets import LabelImgDataset

# %%
tfm = Compose(
    Resize(128, 128),
    Affine(deg=30, shear=(0.3, 0.3), resampling='nearest'),
    Flip(axis=0),
    Flip(axis=1)
)

# %%
ds = LabelImgDataset('./data', tfm)

# %%
for _ in range(10):
    image, bboxes, labels = ds[0]
    display(to_pil(image, bboxes))
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x1A96656C848>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x1A96656C608>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x1A9665808C8>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x1A9665809C8>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x1A966580A88>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x1A966580BC8>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x1A966580D48>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x1A966580CC8>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x1A966580E48>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x1A966580EC8>
