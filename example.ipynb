# %%
from boxaug.transforms import Compose, Affine, Resize, Flip, to_pil
from boxaug.datasets import LabelImgDataset

# %%
tfm = Compose(
    Resize(128, 128),
    Affine(deg=30, shear=(0.3, 0.3)),
    Flip(axis=0),
    Flip(axis=1)
)

# %%
ds = LabelImgDataset('./data', tfm)

# %%
for _ in range(10):
    image, bboxes, labels = ds[0]
    display(to_pil(image, bboxes))
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x15428C93C88>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x15428C93C88>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x15428C93E48>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x15428C93E08>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x15428C93DC8>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x15428C93D08>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x15428C9EB08>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x15428C9EB08>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x15428C9EC48>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x15428C9EC48>
